# %%
import pandas as pd

# %%
 def cleanData(file):
    df = pd.read_csv(f'{file}.csv')
    df = df.loc[~((df['birth year'] == 1969) & (df['gender']==0))]
    df.to_csv(f'{file}_cleaned.csv', index=False)
    return df
    
cleanData('data/201908-citibike-tripdata')
cleanData('data/201912-citibike-tripdata')
cleanData('data/202008-citibike-tripdata')
cleanData('data/202012-citibike-tripdata')
# Out:
#          tripduration                 starttime                  stoptime  \
# 0                 694  2020-12-01 00:00:03.7770  2020-12-01 00:11:38.3160
# 1                4131  2020-12-01 00:00:09.1730  2020-12-01 01:09:00.2370
# 2                1368  2020-12-01 00:00:28.7470  2020-12-01 00:23:16.9980
# 3                1707  2020-12-01 00:00:34.7680  2020-12-01 00:29:02.6470
# 4                2182  2020-12-01 00:00:36.4030  2020-12-01 00:36:59.0330
# ...               ...                       ...                       ...
# 1088921          1178  2020-12-31 23:58:14.1000  2021-01-01 00:17:52.3380
# 1088922          1344  2020-12-31 23:58:17.4800  2021-01-01 00:20:41.6070
# 1088923           589  2020-12-31 23:58:21.2620  2021-01-01 00:08:10.9220
# 1088924          2045  2020-12-31 23:58:21.7040  2021-01-01 00:32:27.1570
# 1088927           654  2020-12-31 23:59:55.9550  2021-01-01 00:10:50.6050
#
#          start station id                   start station name  \
# ...
